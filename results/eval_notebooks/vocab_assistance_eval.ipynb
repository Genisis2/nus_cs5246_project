# %% [markdown]
# # Evaluation of Vocabulary Assistance Method

# %%
import pandas as pd
from simplertimes.vocab import find_diffs, find_potential_matches, eliminate_dupes, get_word_definition
# Out:
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\hansg\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hansg\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hansg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Step 1: Testing on Synthetic Data

# %% [markdown]
# Test the system using some hand-crafted samples and samples from the published outputs of ACCESS.

# %%
infile = 'docs/dev_files/test_sample/vocab_assistance_input_example_data.csv'
outfile = 'vocab_assistance_output_example_data.csv'
in_df = pd.read_csv(infile)
input_data = in_df.itertuples(index=False, name=None)

# %%
final_dict = {}
i = 0
for comp_sentence, simp_sentence in input_data:
    deleted,replaced = find_diffs(comp_sentence, simp_sentence)
    potential_pairs = find_potential_matches(deleted,replaced)
    final_pairs = eliminate_dupes(potential_pairs, replaced)
    for pair in final_pairs:  
        final_dict[i] = {'complicated_sentence': comp_sentence, 'simplified_sentence': simp_sentence, 'difficult_word': pair[0], 'easy_word': pair[1], 'meaning_of_difficult_word': get_word_definition(pair[0].text)}
        i = i + 1

# %%
out_df = pd.DataFrame.from_dict(final_dict, orient='index')
out_df.to_csv(outfile, index=False)
out_df
# Out:
#                                  complicated_sentence  \
# 0                                         i love cats
# 1                                         i love cats
# 2   Theia, a one-year-old bully breed mix, was hit...
# 3   one side of the armed conflicts is composed ma...
# 4   one side of the armed conflicts is composed ma...
# ..                                                ...
# 83  during an interview, edward gorey mentioned th...
# 84  during an interview, edward gorey mentioned th...
# 85  during an interview, edward gorey mentioned th...
# 86  gable also earned an academy award nomination ...
# 87  gable also earned an academy award nomination ...
#
#                                   simplified_sentence difficult_word  \
# 0                                         i like dogs           love
# 1                                         i like dogs           cats
# 2   Theia , a one-year-old breed mix , was hit by ...          bully
# 3   one side of the armed conflict is made up of t...       composed
# 4   one side of the armed conflict is made up of t...         mainly
# ..                                                ...            ...
# 83  during an interview, edward gorey said that ba...      lamenting
# 84  during an interview, edward gorey said that ba...           fact
# 85  during an interview, edward gorey said that ba...           fine
# 86  gable also won an academy award nomination whe...         earned
# 87  gable also won an academy award nomination whe...      portrayed
#
#    easy_word                          meaning_of_difficult_word
# 0       like  a strong positive emotion of regard and affection
# 1       dogs  feline mammal usually having thick soft fur an...
# 2       None                          a cruel and brutal fellow
# 3       None                              form the substance of
# 4       None                                  for the most part
# ..       ...                                                ...
# 83      said                             express grief verbally
# 84      None  a piece of information about circumstances tha...
# 85      best                       money extracted as a penalty
# 86       won  earn on some commercial or business transactio...
# 87    played                                   portray in words
#
# [88 rows x 5 columns]

# %% [markdown]
# ## Step 2: Testing on ACCESS-Simplified ST Dataset

# %% [markdown]
# Test the system using the ACCESS-simplified Straits Times dataset.

# %%
infile = 'results/system_outputs/access_doc_sent_pair_simp.csv'
outfile = 'vocab_assistance_output_access_sent_pairs.csv'
in_df = pd.read_csv(infile)
input_data = in_df.itertuples(index=False, name=None)

# %%
final_dict = {}
i = 0
for _, _, comp_sentence, simp_sentence in input_data:
    deleted,replaced = find_diffs(comp_sentence, simp_sentence)
    potential_pairs = find_potential_matches(deleted,replaced)
    final_pairs = eliminate_dupes(potential_pairs, replaced)
    for pair in final_pairs:  
        final_dict[i] = {'complicated_sentence': comp_sentence, 'simplified_sentence': simp_sentence, 'difficult_word': pair[0], 'easy_word': pair[1], 'meaning_of_difficult_word': get_word_definition(pair[0].text)}
        i = i + 1
# Out:
# c:\Users\hansg\OneDrive\NUS\Classes\2022-2023-Sem2\CS5246\project\nus_cs5246_project\simplertimes\vocab\vocab_assistance.py:43: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   candidate_word[repl_w] = del_w.similarity(repl_w)

# %%
out_df = pd.DataFrame.from_dict(final_dict, orient='index')
out_df.to_csv(outfile, index=False)
out_df
# Out:
#                                   complicated_sentence  \
# 0    The Johor Bahru-Singapore Rapid Transit System...
# 1    45 per cent of the work on the Singapore side ...
# 2    Transport Minister S. Iswaran provided the upd...
# 3    Transport Minister S. Iswaran provided the upd...
# 4    He said: We are on track to achieve the comple...
# ..                                                 ...
# 111  His return to the platforms gives him access t...
# 112  His return to the platforms gives him access t...
# 113  Mr Trump powered his improbable 2016 president...
# 114  YouTube banned Mr Trump in 2021 for violating ...
# 115  YouTube banned Mr Trump in 2021 for violating ...
#
#                                    simplified_sentence difficult_word  \
# 0    The Johor Bahru-Singapore Rapid Transit System...    progressing
# 1    45% of the work on the Singapore side has been...           cent
# 2    Transport Minister S. Iswaran gave the update ...       provided
# 3    Transport Minister S. Iswaran gave the update ...        visited
# 4    He said: We are on track to get the completion...        achieve
# ..                                                 ...            ...
# 111  His return to the platforms gives him a good w...            key
# 112  His return to the platforms gives him a good w...       vehicles
# 113  Mr Trump powered the 2016 presidential campaig...     improbable
# 114  YouTube banned Mr Trump in 2021 for being allo...      violating
# 115  YouTube banned Mr Trump in 2021 for being allo...         policy
#
#     easy_word                          meaning_of_difficult_word
# 0        work                          develop in a positive way
# 1        None    a fractional monetary unit of several countries
# 2        gave              give something useful or necessary to
# 3        went            go to see a place, as for entertainment
# 4        None                                to gain with effort
# ..        ...                                                ...
# 111      good  metal device shaped in such a way that when it...
# 112      None     a conveyance that transports people or objects
# 113      None  not likely to be true or to occur or to have o...
# 114   allowed  fail to agree with; be in violation of; as of ...
# 115      None  a plan of action adopted by an individual or s...
#
# [116 rows x 5 columns]
